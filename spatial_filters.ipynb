# %%
import cv2
import numpy as np
from IPython.display import Image

# %% [markdown]
# AVERAGING FILTER

# %%
# Read the image
img = cv2.imread('sample.png', 0)
img_resize = cv2.resize(img, (300, 400))
cv2.imwrite('sample_resize.png', img_resize)
# Out:
# True

# %%
img = cv2.imread('sample_resize.png', 0)

# %%
display(Image('sample_resize.png'))

# %%
# Obtain number of rows and columns
# of the image
m, n = img.shape

# %%
# Develop Averaging filter(3, 3) mask
mask = np.ones([3, 3], dtype = int)
mask = mask / 9

# %%
# Convolve the 3X3 mask over the image
img_new = np.zeros([m, n])

# %%
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]

        img_new[i, j]= temp

# %%
img_new = img_new.astype(np.uint8)
cv2.imwrite('new.png', img_new)
# Out:
# True

# %%
display(Image('new.png'))

# %%
# Develop Averaging filter(5, 5) mask
mask = np.ones([5, 5], dtype = int)
mask = mask / 25

# %%
# Convolve the 5X5 mask over the image
img_new = np.zeros([m, n])

# %%
for i in range(1, m-1):
    for j in range(1, n-1):
        temp = (img[i-2, j-2]*mask[0, 0]+img[i-2, j-1]*mask[0, 1]+img[i-2, j]*mask[0, 2]+img[i-2, j+1]*mask[0, 3]+img[i-2, j+2]*mask[0, 4])+ (img[i-1, j-2]*mask[1, 0]+img[i-1, j-1]*mask[1, 1]+img[i-1, j]*mask[1, 2]+img[i-1, j+1]*mask[1, 3]+img[i-1, j+2]*mask[1, 4])+(img[i, j-2]*mask[2, 0]+img[i, j-1]*mask[2, 1]+img[i, j]*mask[2, 2]+img[i, j+1]*mask[2, 3]+img[i, j+2]*mask[2, 4])+(img[i+1, j-2]*mask[3, 0]+img[i+1, j-1]*mask[3, 1]+img[i+1, j]*mask[3, 2]+img[i+1, j+1]*mask[3, 3]+img[i+1, j+2]*mask[3, 4])+(img[i+2, j-2]*mask[4, 0]+img[i+2, j-1]*mask[4, 1]+img[i+2, j]*mask[4, 2]+img[i+2, j+1]*mask[4, 3]+img[i+2, j+2]*mask[4, 4])

        img_new[i, j]= temp
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-850348475e68> in <cell line: 1>()
#       1 for i in range(1, m-1):
#       2     for j in range(1, n-1):
# ----> 3         temp = (img[i-2, j-2]*mask[0, 0]+img[i-2, j-1]*mask[0, 1]+img[i-2, j]*mask[0, 2]+img[i-2, j+1]*mask[0, 3]+img[i-2, j+2]*mask[0, 4])+ (img[i-1, j-2]*mask[1, 0]+img[i-1, j-1]*mask[1...
#       4
#       5         img_new[i, j]= temp
#
# IndexError: index 300 is out of bounds for axis 1 with size 300

# %%
img_new = img_new.astype(np.uint8)
cv2.imwrite('new_2.png', img_new)

# %%
display(Image('new_2.png'))
